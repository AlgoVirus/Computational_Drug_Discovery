# %% [markdown]
# # Computational Drug discovery [Part 1] Download Bioactivity Data
# This is the real life Data science project for my **Biological Data Science** Portifolio. Particularly, we will be  building a machine learning model using the ChEMBL bioactivity data.

# %% [markdown]
# ## ChEMBL Database
# The [ChEMBL Database](https://https://www.ebi.ac.uk/chembl/) is a database that conatin curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 target and 18,00 cells and 33,000 indications.[Data as of June 18, 2025]

# %% [markdown]
# ### Installing libraries
# Install the ChEMBL web servicce package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client

# %% [markdown]
# ### Importing libraries

# %%
# importing necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target protein

# %% [markdown]
# ### Target search for coronavirus

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []             Bemisia tabaci
# 8                []  Leptinotarsa decemlineata
# 9                []     Nephotettix cincticeps
# 10               []              Gallus gallus
# 11               []                Danio rerio
# 12               []            Musca domestica
# 13               []          Anopheles gambiae
# 14               []               Homo sapiens
# 15               []        Plutella xylostella
# 16               []            Musca domestica
# 17               []  Pediculus humanus capitis
# 18               []          Spodoptera litura
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for Human acetylcholinesterase (second entry)**
# We will assign the seventh entry (which corresponds to the target protein, Human Acetylcholinesterase) to the ***selected_target***

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# here, we will retrieve only bioactivity data for Human Acetylcholinesterase (CHEMBL220) that are reported as IC50 values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res =  activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9412  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9413                                               None             None
# 9414                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data.csv', index=False)

# %% [markdown]
# # copying files to Google Drive

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google Drive from with in Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# next, we create a data folder in our **Colab Notebooks** folder on Google drive.

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/"
# Out:
# computational_drug_discovery_Acetylcholinesterase_part_1.ipynb	data
# computational_drug_discovery_Acetylcholinesterase_part_2.ipynb	data2

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp acetylcholinestease_01_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# cp: cannot stat 'acetylcholinestease_01_bioactivity_data.csv': No such file or directory

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# total 0

# %% [markdown]
# Let's see the CSV file that we have so far.

# %%
! ls
# Out:
# acetylcholinesterase_01_bioactivity_data.csv		   gdrive
# acetylcholinesterase_02_bioactivity_data_preprocessed.csv  sample_data
# acetylcholinesterase_03_bioactivity_data_curated.csv

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we're just created.

# %%
! head acetylcholinesterase_01_bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# # handling missing data

# %% [markdown]
# If any compunds has missing valuefor standard_value coloumn then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9412  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9413                                               None             None
# 9414                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. but we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# # Data pre-processing of bioactivity data

# %% [markdown]
# #### Labeling compound as either being active, inactive or intermediate
# The bioactivity data is the IC50 unit, Compounds having values of less than 1000nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be refered to as **intermediate**.

# %% [markdown]
# #### Iterate the *molecule_chembl_id, canoniacl_smiles and standard_value* to a list

# %%
selection = ['molecule_chembl_id','canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 9410      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 9411        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 9412      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 9413      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 9414      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#      standard_value
# 0             750.0
# 1             100.0
# ...

# %% [markdown]
# #### Save dataframe to csv file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### labeling compound as either being active, inactive or  intermediate

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 =  pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7897                NaN                                                NaN
# 7926                NaN                                                NaN
# 7927                NaN                                                NaN
# 7928                NaN                                                NaN
# 7930                NaN                                                NaN
#
#      standard_value bioactivity_class
# ...

# %% [markdown]
# Saves dataframe to  CSV file

# %%
df4.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! ls -l
# Out:
# total 6588
# -rw-r--r-- 1 root root 5493157 Jun 20 07:41 acetylcholinesterase_01_bioactivity_data.csv
# -rw-r--r-- 1 root root  579026 Jun 20 07:42 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  657282 Jun 20 07:42 acetylcholinesterase_03_bioactivity_data_curated.csv
# drwx------ 5 root root    4096 Jun 20 07:42 gdrive
# drwxr-xr-x 1 root root    4096 Jun 17 13:37 sample_data

# %% [markdown]
# Let's copy to Google Drive

# %%
! cp bioactivity_data_preprocessed.csv "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# cp: cannot stat 'bioactivity_data_preprocessed.csv': No such file or directory

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/data2"
